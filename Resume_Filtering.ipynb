# %% [markdown]
# <a href="https://colab.research.google.com/github/mradulpandya/Resume-Filtering/blob/main/Resume_Filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
new_df = pd.read_csv("Resume_dataset.csv")

# %%
new_df.head(10)
# Out:
#    index  ...                                             skills
# 0      1  ...  ['Performance Management', 'Human Resources', ...
# 1      2  ...  ['Talent Acquisition', 'Employee Engagement', ...
# 2      3  ...  ['Human Resources', 'Recruiting', 'Team Manage...
# 3      4  ...                                               ['']
# 4      5  ...  ['Team Management', 'Human Resources', 'Employ...
# 5      6  ...  ['Human Resources', 'Employee Engagement', 'Pe...
# 6      7  ...  ['Retail Banking', 'Banking', 'Team Management...
# 7      8  ...  ['Talent Management', 'Human Resources', 'Empl...
# 8      9  ...  ['Requirements Analysis', 'Software Project Ma...
# 9     10  ...  ['Performance Management', 'Employee Engagemen...
#
# [10 rows x 10 columns]

# %%
new_df.tail(10)
# Out:
#       index  ...                                             skills
# 995    1748  ...  ['Aviation', 'Aerospace', 'Airlines', 'Commerc...
# 996    1749  ...  ['Aviation', 'Project Management', 'Program Ma...
# 997    1750  ...  ['Social Media', '3D Studio Max', 'Aircraft Ma...
# 998    1751  ...    ['Civil Aviation', 'Overhaul', 'Flight Safety']
# 999    1752  ...                                               ['']
# 1000   1753  ...                                               ['']
# 1001   1754  ...                                               ['']
# 1002   1755  ...    ['Management', 'Goal Seek', 'Customer Service']
# 1003   1756  ...                         ['Tally ERP', 'Workshops']
# 1004   1757  ...            ['Six Sigma', 'Management', 'Teamwork']
#
# [10 rows x 10 columns]

# %%
new_df.columns
# Out:
# Index(['index', 'category', 'linkedin', 'profile_picture', 'description',
#        'Experience', 'Name', 'position', 'location', 'skills'],
#       dtype='object')

# %%
print(new_df.shape)
# Out:
# (1005, 10)

# %%
new_df.describe()
# Out:
#              index
# count  1005.000000
# mean   1071.397015
# std     557.626116
# min       1.000000
# 25%     888.000000
# 50%    1253.000000
# 75%    1506.000000
# max    1757.000000

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            1005 non-null   int64
#  1   category         1005 non-null   object
#  2   linkedin         1005 non-null   object
#  3   profile_picture  999 non-null    object
#  4   description      542 non-null    object
#  5   Experience       990 non-null    object
#  6   Name             999 non-null    object
#  7   position         999 non-null    object
#  8   location         889 non-null    object
#  9   skills           1005 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 78.6+ KB

# %%
new_df['category'].dtype
# Out:
# dtype('O')

# %%
new_df["category"].describe()
# Out:
# count        1005
# unique         25
# top       Apparel
# freq           50
# Name: category, dtype: object

# %%
new_df["Name"].describe()
# Out:
# count                                    999
# unique                                   975
# top       Building Construction (contractor)
# freq                                       2
# Name: Name, dtype: object

# %%
new_df["location"].describe()
# Out:
# count                       889
# unique                       55
# top       New Delhi Area, India
# freq                        134
# Name: location, dtype: object

# %%
new_df["linkedin"].describe()
# Out:
# count                                          1005
# unique                                          983
# top       https://in.linkedin.com/in/ram-p-b79718b9
# freq                                              2
# Name: linkedin, dtype: object

# %%
new_df["description"].describe()
# Out:
# count        542
# unique       520
# top       #NAME?
# freq           3
# Name: description, dtype: object

# %%
new_df["Experience"].describe()
# Out:
# count                                                   990
# unique                                                  967
# top       Company NameSun International Institute of Tou...
# freq                                                      2
# Name: Experience, dtype: object

# %%
new_df["skills"].describe()
# Out:
# count     1005
# unique     625
# top       ['']
# freq       351
# Name: skills, dtype: object

# %%
new_df["position"].describe()
# Out:
# count     999
# unique    943
# top        --
# freq       14
# Name: position, dtype: object

# %%
new_df["profile_picture"].describe()
# Out:
# count                                                   999
# unique                                                  561
# top       ......
# freq                                                    424
# Name: profile_picture, dtype: object

# %%
new_df["category"].unique()
# Out:
# array(['HR', 'Designing', 'Managment', 'Information Technology',
#        'Education', 'Advocate', 'Business Development',
#        'Health & Fitness', 'Agricultural', 'BPO', 'Sales', 'Consultant',
#        'Digital Media', 'Building & Construction', 'Automobile',
#        'Banking', 'Engineering', 'Food & Beverages', 'Finance', 'Apparel',
#        'Accountant', 'Architects', 'Public Relations', 'Arts', 'Aviation'],
#       dtype=object)

# %%
new_df["location"].unique()
# Out:
# array(['Gurgaon, Haryana, India', 'Pune, Maharashtra, India',
#        'Bengaluru, Karnataka, India', 'Central Delhi, Delhi, India',
#        'Mumbai, Maharashtra, India', 'Ahmedabad, Gujarat, India',
#        'New Delhi Area, India', 'Bengaluru Area, India',
#        'Mumbai Area, India', 'West Delhi, Delhi, India',
#        'Jaipur, Rajasthan, India', 'Hyderabad, Telangana, India',
#        'Coimbatore, Tamil Nadu, India', 'New Delhi, Delhi, India',
#        'Chennai, Tamil Nadu, India', 'Hyderabad Area, India',
#        'Ghaziabad, Uttar Pradesh, India', 'Jaipur, Rajasthan, India ',
#        'South West Delhi, Delhi, India', 'Chennai Area, India', nan,
#        'Indore, Madhya Pradesh, India', 'Lucknow, Uttar Pradesh, India',
#        'North Delhi, Delhi, India', 'East Delhi, Delhi, India',
#        'Noida Area, India', 'Kolkata, West Bengal, India',
#        'South Delhi, Delhi, India', 'Dehradun, Uttarakhand, India',
# ...

# %%
new_df["skills"].unique()
# Out:
# array(["['Performance Management', 'Human Resources', 'Talent Management', 'Talent Acquisition', 'Recruiting', 'Strategy', 'Change Management', 'Deferred Compensation', 'Strategic HR', 'HR Policies', 'Compensation & Benefits', 'Business Strategy', 'Strategic Human Resource Planning', 'Succession Planning', 'Vendor Management', 'Workforce Planning', 'HRIS', 'Personnel Management', 'Employee Relations', 'Management', 'Employee Engagement', 'Leadership', 'Team Management', 'Conflict Management', 'People Skills', 'Performance Appraisal', 'Organizational Structure', 'Certified career coach', 'Certified Hogan assessor and coach']",
# ...

# %%
new_df["position"].unique()
# Out:
# array(['Senior Vice President and Head of HR- Samsung Electronics India Limited',
#        'Head Talent Acquisition and HR Leader for Healthcare Business Unit',
#        'HR@IBM', 'HR',
#        'Vice President - Digital HR Transformation Lead, Global HR Operations / Shared Services and HR Technologies',
#        'HR Location Lead and HR Business Partner',
#        'Head Talent & Performance Mangement and HR Relatioship Head for Corporate Centre verticals at Axis Bank',
#        'VP & Head of HR Technology and HR Shared Services at OYO',
#        'Vice President and Head - Human Capital Management and HR at Nous Infosystems, Bangalore',
#        'Director and HR Head at Umicore',
#        'Talent Acquisition and HR Specialist at Klevu Oy',
#        'Manager (Admin and HR) at Equatus Consultancy and Solutions',
#        'Global HRBP, Products and Customer Success & HR Director, India at FireEye, Inc.',
# ...

# %%
new_df["Experience"].unique()
# Out:
# array(['Senior Vice President & Head of HRCompany NameSamsung Electronics India LimitedDates EmployedJan 2018 – PresentEmployment Duration2 yrs 3 mosLocationGurgaon, Haryana, IndiaVice President Franchise capability building and business transformationCompany NameCoca-Cola India and South West AsiaDates EmployedJan 2017 – Dec 2017Employment Duration12 mosLocationGurgaon, Haryana, IndiaWorked with 17 Franchisees in India and SW asia markets on developing capabilities & talent and make them future ready .Vice President - Human Resources & Services , India & South West AsiaCompany NameCoca Cola India Inc.Dates EmployedJul 2010 – Dec 2016Employment Duration6 yrs 6 mosLed HR & services team for Coca Cola units in India and South West Asia ; Senior Strategic business partner in the regionHead of HR - Services - India/Global EntitiesCompany NameNokia Siemens Networks LimitedDates EmployedJan 2008 – Nov 2010Employment Duration2 yrs 11 mosMember of Business leadership team at region level and
# ...

# %%
new_df["linkedin"].unique()
# Out:
# array(['https://in.linkedin.com/in/sameer-wadhawan-b55134a',
#        'https://in.linkedin.com/in/adarsh-krishna-a4ab0a5',
#        'https://in.linkedin.com/in/shrivas-mohit',
#        'https://in.linkedin.com/in/hr-hopes-086734b8',
#        'https://in.linkedin.com/in/rakeshkumar01',
#        'https://in.linkedin.com/in/yashi-sharma-7b277617',
#        'https://in.linkedin.com/in/suresh-mehra-7593ba69',
#        'https://in.linkedin.com/in/abhay-singh-05982910',
#        'https://in.linkedin.com/in/ajijohnjoseph',
#        'https://in.linkedin.com/in/pooja-shukla-65a17680',
#        'https://in.linkedin.com/in/vandana-patel-06b94a32',
#        'https://in.linkedin.com/in/renu-gupta-068bba57',
#        'https://in.linkedin.com/in/amit-badkas-2084b63',
#        'https://in.linkedin.com/in/deepal-agheda-25a518aa',
#        'https://in.linkedin.com/in/vikram-tadaiya-350b1a54',
#        'https://in.linkedin.com/in/kausik-biswas-56456b56',
# ...

# %%
new_df["profile_picture"].unique()
# Out:
# array(['https://media-exp1.licdn.com/dms/image/C5603AQE0oZw7zBBIpw/profile-displayphoto-shrink_200_200/0?e=1589414400&v=beta&t=DH_9q06YCcRb-GcSwvnrHfZYsuNiP45i41RgygbAtSQ',
#        'https://media-exp1.licdn.com/dms/image/C5103AQHdEjumkMft6A/profile-displayphoto-shrink_200_200/0?e=1589414400&v=beta&t=v3zGk-trDZq0B7Whw6bwieObGt7fVA_GmgbzD9g-aBU',
#        '...',
#        'https://media-exp1.licdn.com/dms/image/C5103AQGm9SpC_yhRDQ/profile-displayphoto-shrink_200_200/0?e=1589414400&v=beta&t=WaP4bxllgqAHy7wXwYIIcUK5xbidO5UH7xriEw45a2Q',
#        'https://media-exp1.licdn.com/dms/image/C5103AQH04m7PTiu6Lw/profile-displayphoto-shrink_200_200/0?e=1589414400&v=beta&t=6wOzWAYpCSgR9eO08ICIhT-QSaXpt9mwgqOICe8k_3Y',
#        'https://media-exp1.licdn.com/dms/image/C4D03AQEYpJGyUjrQNQ/profile-displayphoto-shrink_200_200/0?e=1589414400&v=beta&t=GldAocHCv5xf5XnOnchlS9S3BMM38Xn0NFqf6L7VJs0',
# ...

# %%
new_df["Name"].unique()
# Out:
# array(['Sameer Wadhawan', 'Adarsh Krishna', 'Shrivas Mohit', 'HR Hopes',
#        'Rakesh Kumar', 'Yashi Sharma', 'Suresh Mehra', 'Abhay Singh',
#        'Aji John Joseph', 'Pooja Shukla', 'Vandana Patel', 'Renu Gupta',
#        'Amit Badkas', 'Deepal Agheda', 'Vikram Tadaiya', 'Kausik Biswas',
#        'Guru Prasad', 'Geetanjali Kumar', 'Prasad Keluskar',
#        'Astha Sharma', 'NAVEEN VERMA', 'Roshan Sinha',
#        'Jayashree Gambhir', 'Simi Majumder', 'Rekha Narendra',
#        'Deepa Gangadharan', 'Monika Bhalla', 'Jasmeet Khurana',
#        'Sachidanand R. Kulkarni', 'Gladys Pinheiro', 'Neha Singh',
#        'Kamna Prasad, SPHR®', 'Swarna Kumari T', 'Poonam Chadha',
#        'Parul Murthy', 'Divyaman Ramawat', 'Shivi Khandelwal',
#        'Umesh Jaitane', 'Ashish Saxena', 'Himangi Rao',
#        'Anupama Poovaiah', 'Shashwat K. Mitra', 'Yasmin Commissariat',
#        'Aneree Vasani', 'Voke Natasza Ararile', 'Ajai Pathak',
#        'SHUBHAM RAGHUVANSHI', 'Neha Alexander',
# ...

# %%
new_df["location"].value_counts()
# Out:
# New Delhi Area, India                        134
# Mumbai, Maharashtra, India                   106
# Pune, Maharashtra, India                      85
# Bengaluru, Karnataka, India                   71
# Ahmedabad, Gujarat, India                     44
# Gurgaon, Haryana, India                       43
# New Delhi, Delhi, India                       34
# Chennai, Tamil Nadu, India                    31
# Hyderabad Area, India                         22
# Mumbai Area, India                            21
# Jaipur, Rajasthan, India                      20
# Kolkata, West Bengal, India                   19
# Jaipur, Rajasthan, India                      18
# Gautam Buddha Nagar, Uttar Pradesh, India     15
# Hyderabad, Telangana, India                   15
# Thane, Maharashtra, India                     14
# Central Delhi, Delhi, India                   14
# Bengaluru Area, India                         14
# Indore, Madhya Pradesh, India                 11
# ...

# %%
new_df["skills"].value_counts()
# Out:
# ['']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              351
# ...

# %%
new_df["Name"].value_counts()
# Out:
# Ravi Prabhakar           2
# shailesh shekhar         2
# Uday Kapasi              2
# RAM P                    2
# S Srinivasa Murthy       2
#                         ..
# Sanjay Roy               1
# Nandkishor Sharma        1
# Aarti sawant             1
# Ajai Pathak              1
# Rachapudi Krishnaveni    1
# Name: Name, Length: 975, dtype: int64

# %%
new_df["description"].value_counts()
# Out:
# #NAME?                                                                                                                                                                                                                                                                                                                                                                             3
# Offering one stop solutions to apparel brands and retailers. Applying Arvind's expertise across the textile and apparelvalue chain to provide tailor-made sourcing strategies to customers. Devicing manufacturing strategies with                                                                                                                                                 2
# ...

# %%
new_df["Experience"].value_counts()
# Out:
# Company NameSole ProprietorTotal Duration9 yrs 4 mosTitleNirmal Builder'sDates EmployedDec 2011 – PresentEmployment Duration8 yrs 4 mosLocationNew Delhi Area, IndiaTitleNirmal Builder'sDates EmployedDec 2010 – PresentEmployment Duration9 yrs 4 mosLocationNew Delhi Area, IndiaTitleNirmal Builder'sDates EmployedDec 2011 – PresentEmployment Duration8 yrs 4 mosLocationNew Delhi Area, IndiaTitleNirmal Builder'sDates EmployedDec 2010 – PresentEmployment Duration9 yrs 4 mosLocationNew Delhi Area, IndiaOwnerCompany NameNirmal Builder'sDates EmployedDec 2010 – PresentEmployment Duration9 yrs 4 mos                                                                                                                                                                                                                                                                                                                                                                                                                   
# ...

# %%
new_df["position"].value_counts()
# Out:
# --                                                                     14
# Apparel & Fashion Professional                                          3
# Director                                                                3
# Airlines/Aviation Professional                                          3
# Student at Shri Ramdeobaba College of Engineering and Management        3
#                                                                        ..
# Chartered Accountant and Advocate                                       1
# HR Advisor and Consultant at HR-Is-I                                    1
# Social Media & Digital Marketing | Digital Publishing                   1
# Manager at White Cloud Building Maintenance & Building Construction     1
# Solicitor and advocate                                                  1
# Name: position, Length: 943, dtype: int64

# %%
new_df["category"].value_counts()
# Out:
# Automobile                 50
# Food & Beverages           50
# Architects                 50
# Finance                    50
# Apparel                    50
# Public Relations           50
# Arts                       50
# Engineering                50
# Aviation                   50
# Accountant                 50
# HR                         49
# Banking                    49
# Building & Construction    48
# Digital Media              47
# Consultant                 44
# Sales                      40
# Advocate                   40
# Managment                  39
# Designing                  37
# BPO                        26
# Information Technology     23
# Business Development       22
# Agricultural               18
# Education                  17
# Health & Fitness            6
# Name: category, dtype: int64

# %%
print(new_df['category'].isnull().sum())
# Out:
# 0

# %%
print(new_df['location'].isnull().sum())
# Out:
# 116

# %%
print(new_df['skills'].isnull().sum())
# Out:
# 0

# %%
print(new_df['position'].isnull().sum())
# Out:
# 6

# %%
print(new_df['Experience'].isnull().sum())
# Out:
# 15

# %%
print(new_df['Name'].isnull().sum())
# Out:
# 6

# %%
print(new_df['linkedin'].isnull().sum())
# Out:
# 0

# %%
print(new_df['profile_picture'].isnull().sum())
# Out:
# 6

# %%
print(new_df['description'].isnull().sum())
# Out:
# 463

# %%
print(new_df.isnull().sum())
# Out:
# index                0
# category             0
# linkedin             0
# profile_picture      6
# description        463
# Experience          15
# Name                 6
# position             6
# location           116
# skills               0
# dtype: int64

# %%
sb.heatmap(new_df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
print(new_df.notnull().sum())
# Out:
# index              1005
# category           1005
# linkedin           1005
# profile_picture     999
# description         542
# Experience          990
# Name                999
# position            999
# location            889
# skills             1005
# dtype: int64

# %%
sb.heatmap(new_df.notnull(), cmap='viridis')

# %%
new_df['description'] = new_df['description'].fillna('Description Not Mentioned')

# %%
print(new_df.isnull().sum())
# Out:
# index                0
# category             0
# linkedin             0
# profile_picture      6
# description          0
# Experience          15
# Name                 6
# position             6
# location           116
# skills               0
# dtype: int64

# %%
new_df['location'] = new_df['location'].fillna('Location Not Mentioned')

# %%
print(new_df.isnull().sum())
# Out:
# index               0
# category            0
# linkedin            0
# profile_picture     6
# description         0
# Experience         15
# Name                6
# position            6
# location            0
# skills              0
# dtype: int64

# %%
new_df['Experience'] = new_df['Experience'].fillna('Exceperience Not Mentioned')

# %%
print(new_df.isnull().sum())
# Out:
# index              0
# category           0
# linkedin           0
# profile_picture    6
# description        0
# Experience         0
# Name               6
# position           6
# location           0
# skills             0
# dtype: int64

# %%
new_df['profile_picture'] = new_df['profile_picture'].fillna('Profile picture not available')

# %%
new_df['position'] = new_df['position'].fillna('Position Not Mentioned')

# %%
new_df['Name'] = new_df['Name'].fillna('Name Not Mentioned')

# %%
print(new_df.isnull().sum())
# Out:
# index              0
# category           0
# linkedin           0
# profile_picture    0
# description        0
# Experience         0
# Name               0
# position           0
# location           0
# skills             0
# dtype: int64

# %%
sb.heatmap(new_df.notnull(), cmap='viridis')

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
ax=sb.countplot(x="category", data=new_df)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.01 , p.get_height() * 1.01))
plt.grid()

# %%
plt.figure(figsize=(10,10)) 
plt.scatter(new_df['category'].value_counts(), new_df['category'].unique(), c ="blue")

# To show the plot
plt.show()

# %%
plt.figure(figsize=(10,10))
new_df['category'].value_counts().plot.density(color='green')
plt.title('Density plot for job category')
plt.show()

# %%
sb.distplot(new_df['category'].value_counts(), bins=5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.distplot(new_df['category'].unique(), bins=5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from matplotlib.gridspec import GridSpec
targetCounts = new_df['category'].value_counts()
targetLabels  = new_df['category'].unique()

plt.figure(1, figsize=(25,25))
the_grid = GridSpec(2, 2)


cmap = plt.get_cmap('coolwarm')
colors = [cmap(i) for i in np.linspace(0, 1, 3)]
plt.subplot(the_grid[0, 1], aspect=1, title='CATEGORY DISTRIBUTION')

source_pie = plt.pie(targetCounts, labels=targetLabels, autopct='%1.1f%%', shadow=True, colors=colors)
plt.show()

# %%
x = new_df['location'].value_counts().rename_axis('unique_values').reset_index(name='counts')

plt.figure(figsize=(15,15)) 
plt.scatter(  x['counts'], x['unique_values'],  c ="red")

# %%
plt.figure(figsize=(10,10))
new_df['location'].value_counts().plot.density(color='green')
plt.title('Density plot for Location')
plt.show()

# %%
sb.distplot(new_df['location'].value_counts(), bins=5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from matplotlib.gridspec import GridSpec
x = new_df['location'].value_counts().rename_axis('unique_values').reset_index(name='counts')
targetCounts = x['counts']
targetLabels  = x['unique_values']


plt.figure(1, figsize=(30,30))
the_grid = GridSpec(2, 2)


cmap = plt.get_cmap('Paired')
colors = [cmap(i) for i in np.linspace(0, 1, 3)]
plt.subplot(the_grid[0, 1], aspect=1, title='LOCATION DISTRIBUTION')

source_pie = plt.pie(targetCounts, labels=targetLabels, autopct='%1.1f%%', shadow=True, colors=colors)
plt.show()

# %%
plt.figure(figsize=(20,20))
sb.countplot(hue= 'category', y ='location'  ,data = new_df)

# %%
data = pd.read_csv("Resume_dataset.csv", index_col='location')
rows = data.loc["Mumbai, Maharashtra, India"]

print(type(rows))

rows.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                             index  ...                                             skills
# location                           ...
# Mumbai, Maharashtra, India      7  ...  ['Retail Banking', 'Banking', 'Team Management...
# Mumbai, Maharashtra, India     10  ...  ['Performance Management', 'Employee Engagemen...
# Mumbai, Maharashtra, India     14  ...  ['Compensation & Benefits', 'HR Operations', '...
# Mumbai, Maharashtra, India     18  ...  ['HRIS', 'Human Resources', 'Employee Training...
# Mumbai, Maharashtra, India     39  ...  ['HR Policy Formulation', 'Compensation & Bene...
# Mumbai, Maharashtra, India     42  ...    ['Management', 'Team Management', 'Recruiting']
# Mumbai, Maharashtra, India     46  ...  ['Human Resources', 'Team Management', 'Onboar...
# Mumbai, Maharashtra, India     50  ...    ['Human Resources', 'Recruiting', 'Management']
# ...

# %%
rows = data.loc["Pune, Maharashtra, India"]

print(type(rows))

rows.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                           index  ...                                             skills
# location                         ...
# Pune, Maharashtra, India      2  ...  ['Talent Acquisition', 'Employee Engagement', ...
# Pune, Maharashtra, India      4  ...                                               ['']
# Pune, Maharashtra, India      6  ...  ['Human Resources', 'Employee Engagement', 'Pe...
# Pune, Maharashtra, India     15  ...                                               ['']
# Pune, Maharashtra, India     22  ...  ['Microsoft Office', 'Microsoft Excel', 'Micro...
# Pune, Maharashtra, India     28  ...  ['Agile Methodologies', 'Software Project Mana...
# Pune, Maharashtra, India     30  ...                                               ['']
# Pune, Maharashtra, India     31  ...                                               ['']
# Pune, Maharashtra, India     34  ...  ['Strategy', 'Human Resources', 'Management', ...
# ...

# %%
rows = data.loc["New Delhi, Delhi, India"]

print(type(rows))

rows.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                          index  ...                                             skills
# location                        ...
# New Delhi, Delhi, India     33  ...  ['Employee Engagement', 'Performance Managemen...
# New Delhi, Delhi, India     38  ...  ['Talent Acquisition', 'Employee Relations', '...
# New Delhi, Delhi, India    189  ...  ['Research and Development \\(R&D\\)', 'Electr...
# New Delhi, Delhi, India    195  ...  ['Library Science', 'Cataloging', 'Resource De...
# New Delhi, Delhi, India    252  ...    ['Litigation', 'Legal Advice', 'Corporate Law']
# New Delhi, Delhi, India    289  ...                                               ['']
# New Delhi, Delhi, India    292  ...  ['WTO', 'International Trade Law', 'Litigation...
# New Delhi, Delhi, India    422  ...  ['Auditing', 'Accounting', 'Team Management', ...
# New Delhi, Delhi, India    937  ...  ['Microsoft Office', 'Microsoft Excel', 'Socia...
# ...

# %%
rows = data.loc["Bengaluru, Karnataka, India"]

print(type(rows))

rows.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                              index  ...                                             skills
# location                            ...
# Bengaluru, Karnataka, India      3  ...  ['Human Resources', 'Recruiting', 'Team Manage...
# Bengaluru, Karnataka, India      9  ...  ['Requirements Analysis', 'Software Project Ma...
# Bengaluru, Karnataka, India     16  ...  ['Leadership', 'Strategic Human Resource Plann...
# Bengaluru, Karnataka, India     23  ...  ['HR Analytics', 'Workforce Analytics', 'Busin...
# Bengaluru, Karnataka, India     27  ...  ['Operations Management', 'Program Management'...
# Bengaluru, Karnataka, India     43  ...  ['Team Management', 'Microsoft Office', 'Micro...
# Bengaluru, Karnataka, India     51  ...  ['Architecture', 'Interior Design', 'Project M...
# Bengaluru, Karnataka, India     63  ...         ['Graphic Design', 'Web Design', 'Layout']
# ...

# %%
rows = data.loc["Jaipur, Rajasthan, India"]

print(type(rows))

rows.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                           index  ...                                             skills
# location                         ...
# Jaipur, Rajasthan, India     25  ...  ['Business Analysis', 'Vendor Management', 'Te...
# Jaipur, Rajasthan, India     29  ...  ['HR Policies', 'Management', 'Performance App...
# Jaipur, Rajasthan, India    144  ...             ['Databases', 'SQL*Plus', 'Core Java']
# Jaipur, Rajasthan, India    332  ...  ['Financial Modeling', 'Valuation', 'Corporate...
# Jaipur, Rajasthan, India    347  ...  ['Sports', 'Sports Marketing', 'Sponsorship Sa...
# Jaipur, Rajasthan, India    356  ...  ['Fitness', 'Wellness', 'Exercise Physiology',...
# Jaipur, Rajasthan, India    425  ...                                               ['']
# Jaipur, Rajasthan, India   1059  ...                                               ['']
# Jaipur, Rajasthan, India   1072  ...                                               ['']
# ...

# %%
data = pd.read_csv("Resume_dataset.csv", index_col='category')
rows = data.loc["Information Technology"]

print(type(rows))

rows.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                         index  ...                                             skills
# category                       ...
# Information Technology    152  ...                                               ['']
# Information Technology    154  ...  ['Management', 'Vendor Management', 'Team Mana...
# Information Technology    155  ...  ['Content Development', 'Copy Editing', 'Commu...
# Information Technology    156  ...         ['Public Policy', 'Diplomacy', 'Strategy']
# Information Technology    157  ...  ['IT Management', 'Healthcare Information Tech...
# Information Technology    158  ...  ['Risk Management', 'Fraud', 'Risk Assessment'...
# Information Technology    161  ...  ['IT Service Management', 'Network Security', ...
# Information Technology    165  ...  ['CyberSecurity', 'Information Security Manage...
# Information Technology    170  ...  ['Strategy', 'Market Research', 'Competitive A...
# ...

# %%
rows = data.loc["HR"]

print(type(rows))

rows.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           index  ...                                             skills
# category         ...
# HR            1  ...  ['Performance Management', 'Human Resources', ...
# HR            2  ...  ['Talent Acquisition', 'Employee Engagement', ...
# HR            3  ...  ['Human Resources', 'Recruiting', 'Team Manage...
# HR            4  ...                                               ['']
# HR            5  ...  ['Team Management', 'Human Resources', 'Employ...
# HR            6  ...  ['Human Resources', 'Employee Engagement', 'Pe...
# HR            7  ...  ['Retail Banking', 'Banking', 'Team Management...
# HR            8  ...  ['Talent Management', 'Human Resources', 'Empl...
# HR            9  ...  ['Requirements Analysis', 'Software Project Ma...
# HR           10  ...  ['Performance Management', 'Employee Engagemen...
#
# [10 rows x 9 columns]

# %%
rows = data.loc["Consultant"]

print(type(rows))

rows.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             index  ...                                             skills
# category           ...
# Consultant   1031  ...  ['Consulting', 'E-commerce', 'Project Manageme...
# Consultant   1032  ...   ['Microsoft Office', 'Management', 'Leadership']
# Consultant   1034  ...  ['Employee Engagement', 'Human Resources', 'HR...
# Consultant   1036  ...  ['Training', 'Risk Management', 'Management Co...
# Consultant   1041  ...  ['Team Management', 'Management', 'Vendor Mana...
# Consultant   1042  ...  ['Human Resources', 'Recruiting', 'Temporary P...
# Consultant   1043  ...  ['Pre-sales', 'Solution Selling', 'Team Manage...
# Consultant   1045  ...                                               ['']
# Consultant   1046  ...  ['Pre-sales', 'Solution Selling', 'Team Manage...
# Consultant   1047  ...  ['Team Management', 'Sourcing', 'Sales&Marketi...
#
# [10 rows x 9 columns]

# %%
rows = data.loc["Engineering"]

print(type(rows))

rows.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#              index  ...                                             skills
# category            ...
# Engineering   1210  ...  ['Operations Management', 'Supply Chain Manage...
# Engineering   1213  ...  ['Continuous Improvement', 'Product Developmen...
# Engineering   1216  ...             ['Piping', 'AutoCAD', 'Petrochemical']
# Engineering   1219  ...  ['Engineering', 'AutoCAD', 'Electrical Enginee...
# Engineering   1222  ...                                               ['']
# Engineering   1225  ...          ['Microsoft Project', 'AutoCAD', 'CATIA']
# Engineering   1228  ...                                               ['']
# Engineering   1231  ...  ['Purchasing', 'Materials Management', 'SAP MM...
# Engineering   1234  ...                                               ['']
# Engineering   1237  ...         ['C', 'Manufacturing', 'Microsoft Office']
#
# [10 rows x 9 columns]

# %%
rows = data.loc["Accountant"]

print(type(rows))

rows.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             index  ...                                             skills
# category           ...
# Accountant   1508  ...  ['Corporate Finance', 'Accounting', 'Value-Add...
# Accountant   1509  ...  ['Balance Sheet', 'Profit & Loss Management', ...
# Accountant   1510  ...  ['Accounting', 'Financial Accounting', 'Micros...
# Accountant   1511  ...  ['Leadership', 'Problem Solving', 'Microsoft O...
# Accountant   1512  ...  ['Microsoft Office', 'Leadership', 'Customer S...
# Accountant   1513  ...                  ['Accounting', 'Auditing', 'Tax']
# Accountant   1514  ...  ['Microsoft Office', 'Customer Service', 'Mana...
# Accountant   1515  ...                ['Tax', 'Income Tax', 'Accounting']
# Accountant   1516  ...            ['Tax', 'Income Tax', 'Tax Accounting']
# Accountant   1517  ...  ['Financial Reporting', 'Financial Analysis', ...
#
# [10 rows x 9 columns]

# %%
import pandas as pd
df = pd.read_csv('Resume_dataset.csv')
df['skills'] = df['skills'].str.strip('[]').str.split(',')
new_df1 = df.explode('skills')
new_df1['skills']  = new_df1['skills'].apply(str) 
new_df1['skills'] = new_df1['skills'].str.replace("'", '')

# %%
new_df1
# Out:
#       index  category  ...                    location                  skills
# 0         1        HR  ...     Gurgaon, Haryana, India  Performance Management
# 0         1        HR  ...     Gurgaon, Haryana, India         Human Resources
# 0         1        HR  ...     Gurgaon, Haryana, India       Talent Management
# 0         1        HR  ...     Gurgaon, Haryana, India      Talent Acquisition
# 0         1        HR  ...     Gurgaon, Haryana, India              Recruiting
# ...     ...       ...  ...                         ...                     ...
# 1003   1756  Aviation  ...  Mumbai, Maharashtra, India               Tally ERP
# 1003   1756  Aviation  ...  Mumbai, Maharashtra, India               Workshops
# 1004   1757  Aviation  ...   Thane, Maharashtra, India               Six Sigma
# 1004   1757  Aviation  ...   Thane, Maharashtra, India              Management
# 1004   1757  Aviation  ...   Thane, Maharashtra, India                Teamwork
#
# ...

# %%
new_df1['skills'].describe()
# Out:
# count     6758
# unique    2001
# top
# freq       353
# Name: skills, dtype: object

# %%
new_df1['skills'].value_counts()
# Out:
#                                      353
#  Management                          129
#  Team Management                      94
#  Business Development                 87
#  Marketing                            77
#                                     ...
#  Diplomacy                             1
# Hospitality Industry                   1
#  Switchgear                            1
#  Long-term Customer Relationships      1
# Six Sigma                              1
# Name: skills, Length: 2001, dtype: int64

# %%
plt.figure(figsize=(50,50))
plt.xticks(rotation=90)
ax=sb.countplot(x= new_df1['skills'].value_counts() , data=new_df1)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.01 , p.get_height() * 1.01))
plt.grid()

# %%
new_df1[(new_df1['skills'].values == 'Microsoft Excel')]
# Out:
#      index  ...           skills
# 46      48  ...  Microsoft Excel
# 82      97  ...  Microsoft Excel
# 106    125  ...  Microsoft Excel
# 314    977  ...  Microsoft Excel
# 600   1353  ...  Microsoft Excel
# 632   1385  ...  Microsoft Excel
# 680   1433  ...  Microsoft Excel
# 746   1499  ...  Microsoft Excel
# 858   1611  ...  Microsoft Excel
# 927   1680  ...  Microsoft Excel
# 967   1720  ...  Microsoft Excel
#
# [11 rows x 10 columns]

# %%
new_df1[new_df1.values == 'Human Resources']
# Out:
#      index              category  ...                     location           skills
# 2        3                    HR  ...  Bengaluru, Karnataka, India  Human Resources
# 5        6                    HR  ...     Pune, Maharashtra, India  Human Resources
# 38      40                    HR  ...        Hyderabad Area, India  Human Resources
# 39      41                    HR  ...    Ahmedabad, Gujarat, India  Human Resources
# 44      46                    HR  ...   Mumbai, Maharashtra, India  Human Resources
# 48      50                    HR  ...   Mumbai, Maharashtra, India  Human Resources
# 205    305  Business Development  ...  Bengaluru, Karnataka, India  Human Resources
# 322   1042            Consultant  ...    Ahmedabad, Gujarat, India  Human Resources
# 643   1396      Food & Beverages  ...        New Delhi Area, India  Human Resources
#
# [9 rows x 10 columns]

# %%
new_df1[new_df1.values == 'AutoCAD']
# Out:
#      index                 category  ...                       location   skills
# 80      94                Designing  ...  Coimbatore, Tamil Nadu, India  AutoCAD
# 136    184   Information Technology  ...     Mumbai, Maharashtra, India  AutoCAD
# 332   1054               Consultant  ...     Chennai, Tamil Nadu, India  AutoCAD
# 367   1103  Building & Construction  ...       Pune, Maharashtra, India  AutoCAD
# 439   1190  Building & Construction  ...          New Delhi Area, India  AutoCAD
# 549   1302              Engineering  ...          Ahmedabad Area, India  AutoCAD
# 572   1325              Engineering  ...          New Delhi Area, India  AutoCAD
# 809   1562               Architects  ...     Mumbai, Maharashtra, India  AutoCAD
# 823   1576               Architects  ...                            NaN  AutoCAD
# 830   1583               Architects  ...                            NaN  AutoCAD
# 839   1592               Architects  ...    Bengaluru, Karnataka, India  AutoCAD
# ...

# %%
new_df1[new_df1.values == 'Financial Analysis']
# Out:
#      index    category  ...                        location              skills
# 525   1278     Banking  ...  South West Delhi, Delhi, India  Financial Analysis
# 675   1428     Finance  ...     Kolkata, West Bengal, India  Financial Analysis
# 782   1535  Accountant  ...                             NaN  Financial Analysis
#
# [3 rows x 10 columns]

# %%
new_df1[new_df1.values == 'Social Media Marketing']
# Out:
#      index  ...                  skills
# 362   1094  ...  Social Media Marketing
# 381   1118  ...  Social Media Marketing
# 413   1150  ...  Social Media Marketing
# 415   1152  ...  Social Media Marketing
# 871   1624  ...  Social Media Marketing
#
# [5 rows x 10 columns]

# %%
new_df1[(new_df1['category'].values == 'Engineering') & (new_df1['location'].values == 'Jaipur, Rajasthan, India') ]
# Out:
#      index     category  ...                  location                skills
# 543   1296  Engineering  ...  Jaipur, Rajasthan, India
# 547   1300  Engineering  ...  Jaipur, Rajasthan, India     Civil Engineering
# 547   1300  Engineering  ...  Jaipur, Rajasthan, India   Project Engineering
# 547   1300  Engineering  ...  Jaipur, Rajasthan, India      Project Planning
# 564   1317  Engineering  ...  Jaipur, Rajasthan, India
#
# [5 rows x 10 columns]

# %%
new_df1[(new_df1['category'].values == 'Architects') & (new_df1['skills'].values == 'Architectural Design') ]
# Out:
#      index    category  ...                   location                skills
# 806   1559  Architects  ...  South Delhi, Delhi, India  Architectural Design
# 807   1560  Architects  ...  Jaipur, Rajasthan, India   Architectural Design
# 820   1573  Architects  ...      Ahmedabad Area, India  Architectural Design
# 822   1575  Architects  ...      New Delhi Area, India  Architectural Design
# 840   1593  Architects  ...                        NaN  Architectural Design
#
# [5 rows x 10 columns]

# %%
new_df1[(new_df1['skills'].values == 'Microsoft Excel') & (new_df1['location'].values == 'New Delhi Area, India')]
# Out:
#      index          category  ...               location           skills
# 632   1385  Food & Beverages  ...  New Delhi Area, India  Microsoft Excel
# 680   1433           Finance  ...  New Delhi Area, India  Microsoft Excel
#
# [2 rows x 10 columns]

# %%
new_df1[(new_df1['skills'].values == 'Microsoft Excel') & (new_df1['location'].values == 'New Delhi Area, India') & (new_df1['category'].values == 'Finance')]
# Out:
#      index category  ...               location           skills
# 680   1433  Finance  ...  New Delhi Area, India  Microsoft Excel
#
# [1 rows x 10 columns]
