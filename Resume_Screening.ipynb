# %% [markdown]
# <a href="https://colab.research.google.com/github/mradulpandya/Resume-Screening/blob/main/Resume_Screening.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
new_df = pd.read_csv("Resume_dataset.csv")

# %%
new_df.head()
# Out:
#    index  ...                                       clean_skills
# 0      1  ...  ['Performance Management', 'Human Resources', ...
# 1      2  ...  ['Talent Acquisition', 'Employee Engagement', ...
# 2      3  ...  ['Human Resources', 'Recruiting', 'Team Manage...
# 3      4  ...                                               ['']
# 4      5  ...  ['Team Management', 'Human Resources', 'Employ...
#
# [5 rows x 11 columns]

# %%
new_df.columns
# Out:
# Index(['index', 'category', 'linkedin', 'profile_picture', 'description',
#        'Experience', 'Name', 'position', 'location', 'skills', 'clean_skills'],
#       dtype='object')

# %%
print(new_df.shape)
# Out:
# (1005, 11)

# %%
new_df.describe()
# Out:
#              index
# count  1005.000000
# mean   1071.397015
# std     557.626116
# min       1.000000
# 25%     888.000000
# 50%    1253.000000
# 75%    1506.000000
# max    1757.000000

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            1005 non-null   int64
#  1   category         1005 non-null   object
#  2   linkedin         1005 non-null   object
#  3   profile_picture  999 non-null    object
#  4   description      542 non-null    object
#  5   Experience       990 non-null    object
#  6   Name             999 non-null    object
#  7   position         999 non-null    object
#  8   location         889 non-null    object
#  9   skills           1005 non-null   object
#  10  clean_skills     1005 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 86.5+ KB

# %%
new_df["category"].describe()
# Out:
# count           1005
# unique            25
# top       Architects
# freq              50
# Name: category, dtype: object

# %%
new_df["category"].unique()
# Out:
# array(['HR', 'Designing', 'Managment', 'Information Technology',
#        'Education', 'Advocate', 'Business Development',
#        'Health & Fitness', 'Agricultural', 'BPO', 'Sales', 'Consultant',
#        'Digital Media', 'Building & Construction', 'Automobile',
#        'Banking', 'Engineering', 'Food & Beverages', 'Finance', 'Apparel',
#        'Accountant', 'Architects', 'Public Relations', 'Arts', 'Aviation'],
#       dtype=object)

# %%
new_df["location"].describe()
# Out:
# count                       889
# unique                       55
# top       New Delhi Area, India
# freq                        134
# Name: location, dtype: object

# %%
new_df["location"].value_counts()
# Out:
# New Delhi Area, India                        134
# Mumbai, Maharashtra, India                   106
# Pune, Maharashtra, India                      85
# Bengaluru, Karnataka, India                   71
# Ahmedabad, Gujarat, India                     44
# Gurgaon, Haryana, India                       43
# New Delhi, Delhi, India                       34
# Chennai, Tamil Nadu, India                    31
# Hyderabad Area, India                         22
# Mumbai Area, India                            21
# Jaipur, Rajasthan, India                      20
# Kolkata, West Bengal, India                   19
# Jaipur, Rajasthan, India                      18
# Gautam Buddha Nagar, Uttar Pradesh, India     15
# Hyderabad, Telangana, India                   15
# Central Delhi, Delhi, India                   14
# Thane, Maharashtra, India                     14
# Bengaluru Area, India                         14
# Indore, Madhya Pradesh, India                 11
# ...

# %%
new_df["category"].value_counts()
# Out:
# Architects                 50
# Engineering                50
# Automobile                 50
# Apparel                    50
# Food & Beverages           50
# Public Relations           50
# Finance                    50
# Accountant                 50
# Aviation                   50
# Arts                       50
# HR                         49
# Banking                    49
# Building & Construction    48
# Digital Media              47
# Consultant                 44
# Sales                      40
# Advocate                   40
# Managment                  39
# Designing                  37
# BPO                        26
# Information Technology     23
# Business Development       22
# Agricultural               18
# Education                  17
# Health & Fitness            6
# Name: category, dtype: int64

# %%
for column in new_df.columns:
  try:
    print("The Values of column",column,"are:",new_df[column].value_counts())
    print("---"*40)
  except:
    pass
# Out:
# The Values of column index are: 1757    1
# 894     1
# 424     1
# 423     1
# 422     1
#        ..
# 1307    1
# 1306    1
# 1305    1
# 1304    1
# 1       1
# Name: index, Length: 1029, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# The Values of column category are: Accountant                 50
# Public Relations           50
# Sales                      50
# Digital Media              49
# Information Technology     48
# Building & Construction    48
# Health & Fitness           47
# Automobile                 47
# Advocate                   47
# Designing                  45
# Business Development       45
# Engineering                45
# Banking                    45
# Consultant                 44
# Agricultural               43
# Finance                    41
# HR                         39
# Aviation                   38
# Architects                 34
# ...

# %%
print(new_df.isnull().sum())
# Out:
# index                0
# category             0
# linkedin             0
# profile_picture      6
# description        463
# Experience          15
# Name                 6
# position             6
# location           116
# skills               0
# clean_skills         0
# dtype: int64

# %%
sb.heatmap(new_df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
plt.figure(figsize=(20,20))
sb.countplot(hue= 'category', y ='location'  ,data = new_df)

# %%
plt.figure(figsize=(25,25))
sb.countplot(y= 'location', data = new_df, palette='Set2')

# %%
from matplotlib.gridspec import GridSpec
targetCounts = new_df['category'].value_counts()
targetLabels  = new_df['category'].unique()

plt.figure(1, figsize=(25,25))
the_grid = GridSpec(2, 2)


cmap = plt.get_cmap('coolwarm')
colors = [cmap(i) for i in np.linspace(0, 1, 3)]
plt.subplot(the_grid[0, 1], aspect=1, title='CATEGORY DISTRIBUTION')

source_pie = plt.pie(targetCounts, labels=targetLabels, autopct='%1.1f%%', shadow=True, colors=colors)
plt.show()

# %%
new_df['location'].value_counts()
# Out:
# New Delhi Area, India                        134
# Mumbai, Maharashtra, India                   106
# Pune, Maharashtra, India                      85
# Bengaluru, Karnataka, India                   71
# Ahmedabad, Gujarat, India                     44
# Gurgaon, Haryana, India                       43
# New Delhi, Delhi, India                       34
# Chennai, Tamil Nadu, India                    31
# Hyderabad Area, India                         22
# Mumbai Area, India                            21
# Jaipur, Rajasthan, India                      20
# Kolkata, West Bengal, India                   19
# Jaipur, Rajasthan, India                      18
# Gautam Buddha Nagar, Uttar Pradesh, India     15
# Hyderabad, Telangana, India                   15
# Central Delhi, Delhi, India                   14
# Thane, Maharashtra, India                     14
# Bengaluru Area, India                         14
# Indore, Madhya Pradesh, India                 11
# ...

# %%
new_df['skills'].value_counts()
# Out:
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            351
# ...

# %%
data = pd.read_csv("Resume_dataset.csv", index_col='location')
rows = data.loc["Mumbai, Maharashtra, India"]

print(type(rows))

rows.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                             index  ...                                       clean_skills
# location                           ...
# Mumbai, Maharashtra, India      7  ...  ['Retail Banking', 'Banking', 'Team Management...
# Mumbai, Maharashtra, India     10  ...  ['Performance Management', 'Employee Engagemen...
# Mumbai, Maharashtra, India     14  ...  ['Compensation & Benefits', 'HR Operations', '...
# Mumbai, Maharashtra, India     18  ...  ['HRIS', 'Human Resources', 'Employee Training...
# Mumbai, Maharashtra, India     39  ...  ['HR Policy Formulation', 'Compensation & Bene...
# Mumbai, Maharashtra, India     42  ...    ['Management', 'Team Management', 'Recruiting']
# Mumbai, Maharashtra, India     46  ...  ['Human Resources', 'Team Management', 'Onboar...
# Mumbai, Maharashtra, India     50  ...    ['Human Resources', 'Recruiting', 'Management']
# ...

# %%
rows = data.loc["Bengaluru, Karnataka, India"]

print(type(rows))

rows.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                              index  ...                                       clean_skills
# location                            ...
# Bengaluru, Karnataka, India      3  ...  ['Human Resources', 'Recruiting', 'Team Manage...
# Bengaluru, Karnataka, India      9  ...  ['Requirements Analysis', 'Software Project Ma...
# Bengaluru, Karnataka, India     16  ...  ['Leadership', 'Strategic Human Resource Plann...
# Bengaluru, Karnataka, India     23  ...  ['HR Analytics', 'Workforce Analytics', 'Busin...
# Bengaluru, Karnataka, India     27  ...  ['Operations Management', 'Program Management'...
#
# [5 rows x 10 columns]

# %%
data = pd.read_csv("Resume_dataset.csv", index_col='category')
rows = data.loc["Information Technology"]

print(type(rows))

rows.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                         index  ...                                       clean_skills
# category                       ...
# Information Technology    152  ...                                               ['']
# Information Technology    154  ...  ['Management', 'Vendor Management', 'Team Mana...
# Information Technology    155  ...  ['Content Development', 'Copy Editing', 'Commu...
# Information Technology    156  ...         ['Public Policy', 'Diplomacy', 'Strategy']
# Information Technology    157  ...  ['IT Management', 'Healthcare Information Tech...
# Information Technology    158  ...  ['Risk Management', 'Fraud', 'Risk Assessment'...
# Information Technology    161  ...  ['IT Service Management', 'Network Security', ...
# Information Technology    165  ...  ['CyberSecurity', 'Information Security Manage...
# Information Technology    170  ...  ['Strategy', 'Market Research', 'Competitive A...
# ...
